# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data_extracted_laptop.csv')

# %% [markdown]
# # Removing unnecesary columns like - "Unnamed :0"

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df.head()
# Out:
#                                                 name    price             os  \
# 0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  ₹52,000  Windows 11 OS
# 1  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  ₹37,990  Windows 11 OS
# 2  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  ₹59,990  Windows 11 OS
# 3  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  ₹55,990  Windows 11 OS
# 4  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  ₹39,790  Windows 11 OS
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# ...

# %%
df.isna().sum()
# Out:
# name            0
# price           0
# os              0
# graphics        0
# display         0
# ram             0
# rom             0
# warranty        3
# rating        268
# core            0
# intel_core      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        760 non-null    object
#  1   price       760 non-null    object
#  2   os          760 non-null    object
#  3   graphics    760 non-null    object
#  4   display     760 non-null    object
#  5   ram         760 non-null    object
#  6   rom         760 non-null    object
#  7   warranty    757 non-null    object
#  8   rating      492 non-null    float64
#  9   core        760 non-null    object
#  10  intel_core  760 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 65.4+ KB

# %% [raw]
#  Cleaning the price column

# %%
df['price']=df['price'].str.replace("₹","")

# %%
df['price']=df['price'].str.replace(",","")

# %%
df['price']=df['price'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        760 non-null    object
#  1   price       760 non-null    int32
#  2   os          760 non-null    object
#  3   graphics    760 non-null    object
#  4   display     760 non-null    object
#  5   ram         760 non-null    object
#  6   rom         760 non-null    object
#  7   warranty    757 non-null    object
#  8   rating      492 non-null    float64
#  9   core        760 non-null    object
#  10  intel_core  760 non-null    object
# dtypes: float64(1), int32(1), object(9)
# memory usage: 62.5+ KB

# %%
df['os'].value_counts()
# Out:
# Windows 11 OS                      657
# Windows 10 OS                       18
# Mac OS                              17
# 15.6 inches, 1920 x 1080 pixels     12
# Chrome OS                           12
# 1 Year Warranty                     11
# Windows OS                           9
# DOS OS                               7
# Windows 10  OS                       6
# Windows 11  OS                       6
# Android 11 OS                        1
# DOS 3.0 OS                           1
# Ubuntu OS                            1
# 15.6 inches, 1366 x 768 pixels       1
# 14 inches, 1920 x 1080 pixels        1
# Name: os, dtype: int64

# %%
df[df['os'].str.contains("Windows")]
# Out:
#                                                   name  price             os  \
# 0    HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  Windows 11 OS
# 1    HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  Windows 11 OS
# 2    Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  Windows 11 OS
# 3    Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  Windows 11 OS
# 4    Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  Windows 11 OS
# ..                                                 ...    ...            ...
# 755  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101  Windows 11 OS
# 756  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388  Windows 11 OS
# 757  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990  Windows 11 OS
# 758  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440  Windows 11 OS
# 759  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990  Windows 11 OS
#
#                          graphics  \
# ...

# %%
df
# Out:
#                                                   name  price             os  \
# 0    HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  Windows 11 OS
# 1    HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  Windows 11 OS
# 2    Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  Windows 11 OS
# 3    Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  Windows 11 OS
# 4    Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  Windows 11 OS
# ..                                                 ...    ...            ...
# 755  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101  Windows 11 OS
# 756  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388  Windows 11 OS
# 757  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990  Windows 11 OS
# 758  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440  Windows 11 OS
# 759  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990  Windows 11 OS
#
#                          graphics  \
# ...

# %%
df.reset_index(inplace=True)

# %%
df['index']=df['index']+1

# %%
df
# Out:
#      index                                               name  price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000
# 1        2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990
# 2        3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990
# 3        4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990
# 4        5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790
# ..     ...                                                ...    ...
# 755    756  Lenovo IdeaPad Flex 5 82Y00053IN Laptop (13th ...  91101
# 756    757  Lenovo Ideapad Slim 5 82XE004QIN Laptop (AMD R...  66388
# 757    758  Asus Vivobook Pro 15 M6500QC-HN551WS Laptop (A...  69990
# 758    759  Dell 15 Inspiron 3530 Laptop (13th Gen Core i5...  63440
# 759    760  Asus Vivobook 16X 2023 K3605ZC-MBN752WS Laptop...  98990
#
#                 os                      graphics  \
# 0    Windows 11 OS      4 GB AMD Radeon RX 6500M
# ...

# %%
temp_df1=df[df['os'].str.contains("pixels")]

# %%
temp_df1['rom'] = temp_df1['rom']+ "+" + " "+ temp_df1['graphics']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\332648988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['rom'] = temp_df1['rom']+ "+" + " "+ temp_df1['graphics']

# %%
temp_df1
# Out:
#      index                                               name  price  \
# 61      62  MSI GF63 Thin 11UC-1294IN Gaming Laptop (11th ...  65990
# 163    164  MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th...  53990
# 165    166  MSI Thin GF63 11UC-1490IN Gaming Laptop (11th ...  57990
# 298    299  Dell Inspiron 3520 Laptop (12th Gen Core i5/ 8...  50990
# 299    300  Dell Inspiron 3520 D560879WIN9S Laptop (12th G...  60990
# 317    318  HP 15s-GR0012AU Laptop (AMD Ryzen 3 3250U/ 8GB...  37290
# 431    432  Dell Vostro 15 3510 Laptop (11th Gen Core i3/ ...  36990
# 476    477  MSI GF63 Thin 11SC-1298IN Gaming Laptop (11th ...  59990
# 482    483  MSI Thin GF63 12VF-268IN Laptop (12th Gen Core...  86990
# 488    489  HP 250 G8 7M6L7PA Laptop (11th Gen Core i3/ 8G...  37790
# 575    576  HP 15s-dr3506TU Laptop (11th Gen Core i3/ 8GB/...  35999
# 618    619  Dell Inspiron 3511 Laptop (11th Gen Core i5/ 8...  64000
# 622    623  Dell Inspiron 3501 Laptop (11th Gen Core i5/ 8...  52500
# ...

# %%
temp_df1['graphics']=temp_df1['display']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\469393929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['graphics']=temp_df1['display']

# %%
temp_df1
# Out:
#      index                                               name  price  \
# 61      62  MSI GF63 Thin 11UC-1294IN Gaming Laptop (11th ...  65990
# 163    164  MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th...  53990
# 165    166  MSI Thin GF63 11UC-1490IN Gaming Laptop (11th ...  57990
# 298    299  Dell Inspiron 3520 Laptop (12th Gen Core i5/ 8...  50990
# 299    300  Dell Inspiron 3520 D560879WIN9S Laptop (12th G...  60990
# 317    318  HP 15s-GR0012AU Laptop (AMD Ryzen 3 3250U/ 8GB...  37290
# 431    432  Dell Vostro 15 3510 Laptop (11th Gen Core i3/ ...  36990
# 476    477  MSI GF63 Thin 11SC-1298IN Gaming Laptop (11th ...  59990
# 482    483  MSI Thin GF63 12VF-268IN Laptop (12th Gen Core...  86990
# 488    489  HP 250 G8 7M6L7PA Laptop (11th Gen Core i3/ 8G...  37790
# 575    576  HP 15s-dr3506TU Laptop (11th Gen Core i3/ 8GB/...  35999
# 618    619  Dell Inspiron 3511 Laptop (11th Gen Core i5/ 8...  64000
# 622    623  Dell Inspiron 3501 Laptop (11th Gen Core i5/ 8...  52500
# ...

# %%
temp_df1['display']=temp_df1['os']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\2231681460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['display']=temp_df1['os']

# %%
temp_df1['os']=temp_df1['warranty']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\1730586659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['os']=temp_df1['warranty']

# %%
temp_df1['warranty']=np.nan
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\3561653305.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df1['warranty']=np.nan

# %%
temp_df1
# Out:
#      index                                               name  price  \
# 61      62  MSI GF63 Thin 11UC-1294IN Gaming Laptop (11th ...  65990
# 163    164  MSI Thin GF63 11UCX-1492IN Gaming Laptop (11th...  53990
# 165    166  MSI Thin GF63 11UC-1490IN Gaming Laptop (11th ...  57990
# 298    299  Dell Inspiron 3520 Laptop (12th Gen Core i5/ 8...  50990
# 299    300  Dell Inspiron 3520 D560879WIN9S Laptop (12th G...  60990
# 317    318  HP 15s-GR0012AU Laptop (AMD Ryzen 3 3250U/ 8GB...  37290
# 431    432  Dell Vostro 15 3510 Laptop (11th Gen Core i3/ ...  36990
# 476    477  MSI GF63 Thin 11SC-1298IN Gaming Laptop (11th ...  59990
# 482    483  MSI Thin GF63 12VF-268IN Laptop (12th Gen Core...  86990
# 488    489  HP 250 G8 7M6L7PA Laptop (11th Gen Core i3/ 8G...  37790
# 575    576  HP 15s-dr3506TU Laptop (11th Gen Core i3/ 8GB/...  35999
# 618    619  Dell Inspiron 3511 Laptop (11th Gen Core i5/ 8...  64000
# 622    623  Dell Inspiron 3501 Laptop (11th Gen Core i5/ 8...  52500
# ...

# %%
df.loc[temp_df1.index,temp_df1.columns]=temp_df1.values

# %%
df['os'].value_counts()
# Out:
# Windows 11 OS      666
# Windows 10 OS       22
# Mac OS              17
# Chrome OS           12
# 1 Year Warranty     11
# Windows OS           9
# DOS OS               7
# Windows 11  OS       7
# Windows 10  OS       6
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: os, dtype: int64

# %%
temp_df2=df[df['os'].str.contains("Warranty") & df['display'].str.contains("pixels") ]

# %%
temp_df2['warranty']
# Out:
# 51     2 USB 3.0 Ports
# 145    2 USB 3.0 Ports
# 414                NaN
# 683    2 USB 3.0 Ports
# Name: warranty, dtype: object

# %%
temp_df2['warranty']=temp_df2['os']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\555395982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df2['warranty']=temp_df2['os']

# %%
temp_df2['os']=np.nan
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\2610167317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df2['os']=np.nan

# %%
df.loc[temp_df2.index,temp_df2.columns]=temp_df2.values

# %%
df['os'].value_counts()
# Out:
# Windows 11 OS      666
# Windows 10 OS       22
# Mac OS              17
# Chrome OS           12
# Windows OS           9
# DOS OS               7
# 1 Year Warranty      7
# Windows 11  OS       7
# Windows 10  OS       6
# Android 11 OS        1
# DOS 3.0 OS           1
# Ubuntu OS            1
# Name: os, dtype: int64

# %%
temp_df3=df[df['os']=='1 Year Warranty']

# %%
temp_df3
# Out:
#      index                                               name   price  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990
# 81      82  Acer C733 NX.H8VSI.004 Chromebook (Celeron Dua...    9990
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990
# 601    602  Samsung Galaxy Book Go Laptop (Snapdragon 7c/ ...   29990
# 612    613  Lenovo Chromebook 3 82BA0003US Laptop (Intel C...   35842
# 614    615  Lenovo IdeaPad 3 CB 11IGL05 82BA001PHA Laptop ...   17600
# 621    622  HP 11A-NA0002MU Chromebook (MT8183/ 4GB/ 64GB ...   17990
#
#                   os                                      graphics  \
# 67   1 Year Warranty               15.6 inches, 1920 x 1080 pixels
# 81   1 Year Warranty                11.6 inches, 1366 x 768 pixels
# 495  1 Year Warranty               15.6 inches, 1920 x 1080 pixels
# 601  1 Year Warranty                 14 inches, 1920 x 1080 pixels
# 612  1 Year Warranty                11.6 inches, 1366 x 768 pixels
# ...

# %%
temp_df3['warranty']=temp_df3['os']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\125083596.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['warranty']=temp_df3['os']

# %%
temp_df3['os']=temp_df3['display']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\4196719916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['os']=temp_df3['display']

# %%
temp_df3['display']=temp_df3['graphics']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\722555688.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['display']=temp_df3['graphics']

# %%
temp_df3['graphics']=temp_df3['rom']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\1813169312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['graphics']=temp_df3['rom']

# %%
temp_df3['rom']=np.nan
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\851502817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df3['rom']=np.nan

# %%
temp_df3
# Out:
#      index                                               name   price  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990
# 81      82  Acer C733 NX.H8VSI.004 Chromebook (Celeron Dua...    9990
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990
# 601    602  Samsung Galaxy Book Go Laptop (Snapdragon 7c/ ...   29990
# 612    613  Lenovo Chromebook 3 82BA0003US Laptop (Intel C...   35842
# 614    615  Lenovo IdeaPad 3 CB 11IGL05 82BA001PHA Laptop ...   17600
# 621    622  HP 11A-NA0002MU Chromebook (MT8183/ 4GB/ 64GB ...   17990
#
#                 os                      graphics  \
# 67   Windows 11 OS  8 GB NVIDIA GeForce RTX 4060
# 81       Chrome OS      Intel Integrated UHD 600
# 495         DOS OS   Intel Integrated Integrated
# 601  Windows 11 OS               Qualcomm Adreno
# 612      Chrome OS        Intel UHD Graphics 600
# 614      Chrome OS          Intel Integrated UHD
# 621      Chrome OS           MediaTek Integrated
#
# ...

# %%
df.loc[temp_df3.index,temp_df3.columns]=temp_df3.values

# %%
df['os']=df['os'].str.strip()

# %%
df['os'].value_counts()
# Out:
# Windows 11 OS     668
# Windows 10 OS      22
# Mac OS             17
# Chrome OS          16
# Windows OS          9
# DOS OS              8
# Windows 11  OS      7
# Windows 10  OS      6
# Android 11 OS       1
# DOS 3.0 OS          1
# Ubuntu OS           1
# Name: os, dtype: int64

# %%
df['os']=df['os'].fillna("")

# %%
df['os'].value_counts()
# Out:
# Windows 11 OS     668
# Windows 10 OS      22
# Mac OS             17
# Chrome OS          16
# Windows OS          9
# DOS OS              8
# Windows 11  OS      7
# Windows 10  OS      6
#                     4
# Android 11 OS       1
# DOS 3.0 OS          1
# Ubuntu OS           1
# Name: os, dtype: int64

# %%
temp_df4=df[df['os'].str.contains("Windows")]

# %%
temp_df4['os'].value_counts()
# Out:
# Windows 11 OS     668
# Windows 10 OS      22
# Windows OS          9
# Windows 11  OS      7
# Windows 10  OS      6
# Name: os, dtype: int64

# %%
temp_df4['os']="windows"
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\1367928528.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df4['os']="windows"

# %%
temp_df4['os'].value_counts()
# Out:
# windows    712
# Name: os, dtype: int64

# %%
df.loc[temp_df4.index,temp_df4.columns]=temp_df4.values

# %%
df['os'].value_counts()
# Out:
# windows          712
# Mac OS            17
# Chrome OS         16
# DOS OS             8
#                    4
# Android 11 OS      1
# DOS 3.0 OS         1
# Ubuntu OS          1
# Name: os, dtype: int64

# %%
temp_df5=df[df['os']=="Mac OS"]

# %%
temp_df5['os']="mac"
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\333127256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df5['os']="mac"

# %%
df.loc[temp_df5.index,temp_df5.columns]=temp_df5.values

# %%
df['os'].value_counts()
# Out:
# windows          712
# mac               17
# Chrome OS         16
# DOS OS             8
#                    4
# Android 11 OS      1
# DOS 3.0 OS         1
# Ubuntu OS          1
# Name: os, dtype: int64

# %%
temp_df6=df[df['os'].str.contains("OS")]

# %%
temp_df6['os']="other"
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\3447078054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df6['os']="other"

# %%
temp_df6['os'].value_counts()
# Out:
# other    27
# Name: os, dtype: int64

# %%
df.loc[temp_df6.index,temp_df5.columns]=temp_df6.values

# %%
df['os'].value_counts()
# Out:
# windows    712
# other       27
# mac         17
#              4
# Name: os, dtype: int64

# %%
df['os']=df['os'].replace("",np.nan)

# %%
df['os'].value_counts()
# Out:
# windows    712
# other       27
# mac         17
# Name: os, dtype: int64

# %%
#graphics column
df['graphics'].value_counts()
# Out:
# Intel Iris Xe Graphics          70
# Intel UHD Graphics              57
# Intel Integrated UHD            54
# 4 GB NVIDIA GeForce RTX 3050    52
# Intel Integrated Iris Xe        44
#                                 ..
# AMD Radeon Vega 8                1
# Intel HD                         1
# AMD Radeon Vega 6                1
# Intel Iris Xe Graphics           1
# 4 GB NVIDIA GeForce GTX 2050     1
# Name: graphics, Length: 129, dtype: int64

# %%
pd.set_option('display.max_rows',760)

# %%
df['graphics']=df['graphics'].str.strip()

# %%
#display
df['display']=df['display'].str.strip()

# %%
df['display'].value_counts()
# Out:
# 15.6 inches, 1920 x 1080 pixels                  391
# 14 inches, 1920 x 1080 pixels                     87
# 16 inches, 1920 x 1200 pixels                     36
# 16 inches, 2560 x 1600 pixels                     24
# 14 inches, 1920 x 1200 pixels, Touch Screen       19
# 14 inches, 1920 x 1200 pixels                     16
# 14 inches, 2880 x 1800 pixels                     15
# 15.6 inches, 1366 x 768 pixels                    14
# 11.6 inches, 1366 x 768 pixels                    13
# 16.1 inches, 1920 x 1080 pixels                   10
# 17.3 inches, 1920 x 1080 pixels                    8
# 14 inches, 1920 x 1080 pixels, Touch Screen        8
# 14 inches, 1366 x 768 pixels                       7
# 14.2 inches, 3024 x 1964 pixels                    6
# 14 inches, 2880 x 1800 pixels, Touch Screen        5
# 15.6 inches, 1920 x 1080 pixels, Touch Screen      5
# 13.3 inches, 2560 x 1600 pixels                    5
# 15.6 inches, 2560 x 1440 pixels                    4
# ...

# %%
temp_df7=df[df['display'].str.contains("Touch Screen")]

# %%
temp_df7['Touchscreen']="touchscreen"
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\2310004900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df7['Touchscreen']="touchscreen"

# %%
temp_df7
# Out:
#      index                                               name   price  \
# 0        1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...   52000
# 99     100  Asus ROG Flow X13 GV301RC-LJ073WS Gaming Lapto...  131990
# 124    125  Asus Vivobook S14 Flip 2022 TN3402QA-LZ741WS L...   64990
# 132    133  HP Chromebook 14a-na1004TU Laptop (Celeron N45...   17990
# 154    155  Dell Latitude 7440 14 Laptop (13th Gen Core i5...  152000
# 155    156  Lenovo Yoga 7 82YM0074IN Laptop (AMD Ryzen 7 7...   97990
# 156    157  Dell Latitude 7440 Laptop (13th Gen Core i5/ 1...  152000
# 191    192  HP Pavilion x360 14-ek1010TU Laptop (13th Gen ...   77889
# 205    206  Asus Vivobook 15 Touch X515EA-EZ311WS Laptop (...   38990
# 208    209  Lenovo Tab Yoga Duet 7 (11th Gen Core i5/ 8GB/...   47999
# 230    231  Asus Chromebook CX1400FKA-EC0158 Laptop (Celer...   20990
# 257    258  Dell XPS 17 9730 Laptop (13th Gen Core i9/ 32G...  354490
# ...

# %%
df.loc[temp_df7.index,temp_df7.columns]=temp_df7.values

# %%
df.head(4)
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# 3                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
#
#           rom         warranty  rating                            core  \
# ...

# %%
df['ram'].value_counts()
# Out:
# 8 GB DDR4 RAM               224
# 16 GB DDR4 RAM              208
# 16 GB DDR5 RAM               76
# 16 GB LPDDR5 RAM             43
# 8 GB LPDDR5 RAM              36
# 8 GB DDR5 RAM                19
# 16 GB LPDDR4X RAM            16
# 32 GB DDR5 RAM               15
# 8 GB LPDDR4X RAM             13
# 4 GB DDR4 RAM                10
# 8 GB  RAM                    10
# 16 GB  LPDDR5 RAM             8
# 16 GB LPDDR4x RAM             7
# 4 GB LPDDR4 RAM               7
# 8 GB DDR4  RAM                6
# 16 GB  RAM                    6
# 8 GB LPDDR4 RAM               5
# 16 GB LPDDR4 RAM              5
# 32 GB LPDDR5 RAM              3
# 18 GB  RAM                    3
# 64 GB DDR5 RAM                3
# 8 GB LPDDR5  RAM              3
# 16 GB LPDDR5  RAM             3
# 16 GB Unified Memory RAM      2
# 8 GB LPDDR4x RAM              2
# 32 GB LPDDR5X RAM             2
# 4 GB LPDDR4X RAM              2
# 16 GB LPDDR5X RAM             2
# 4 GB LPDDR4x RAM              2
# ...

# %%
temp_df8=df[df['ram'].str.contains("SSD")]

# %%
temp_df8['rom']=temp_df8['ram']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\612315206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df8['rom']=temp_df8['ram']

# %%
temp_df8['ram']=temp_df8['core']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\3876874577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df8['ram']=temp_df8['core']

# %%
temp_df8
# Out:
#      index                                               name   price  \
# 67      68  Lenovo LOQ 15IRH8 82XV00BRIN 2023 Gaming Lapto...  114990
# 495    496  ‎Lenovo V15 G2 IJL 82QYA00HIN Laptop (Celeron ...   21990
#
#           os                      graphics                          display  \
# 67   windows  8 GB NVIDIA GeForce RTX 4060  15.6 inches, 1920 x 1080 pixels
# 495    other   Intel Integrated Integrated  15.6 inches, 1920 x 1080 pixels
#
#                 ram         rom         warranty  rating            core  \
# 67   16 GB DDR5 RAM  512 GB SSD  1 Year Warranty    63.0  16 GB DDR5 RAM
# 495   8 GB DDR4 RAM  256 GB SSD  1 Year Warranty     NaN   8 GB DDR4 RAM
#
#                  intel_core Touchscreen
# 67   13th Gen Intel Core i7         NaN
# 495    Intel Celeron  N4500         NaN

# %%
df.loc[temp_df8.index,temp_df8.columns]=temp_df8.values

# %%
df['warranty'].value_counts()
# Out:
# 1 Year Warranty     691
# 2 Year Warranty      40
# 3 Year Warranty      10
# Backlit Keyboard      5
# Name: warranty, dtype: int64

# %%
df[df['warranty']=="Backlit Keyboard"]
# Out:
#      index                                               name   price  \
# 154    155  Dell Latitude 7440 14 Laptop (13th Gen Core i5...  152000
# 156    157  Dell Latitude 7440 Laptop (13th Gen Core i5/ 1...  152000
# 496    497  Dell Precision 3470 Laptop (12th Gen Core i5/ ...  113000
# 527    528  HP 15s-eq2213AU Laptop (AMD Ryzen 3 5300U/ 8GB...   31999
# 623    624  HP Omen 15-ek0025tx Laptop (10th Gen Core i5/ ...   69999
#
#           os                      graphics  \
# 154  windows        Intel Iris Xe Graphics
# 156  windows        Intel Iris Xe Graphics
# 496  windows              4 GB NVIDIA T550
# 527  windows           AMD Radeon Graphics
# 623  windows  4 GB NVIDIA Geforce GTX 1650
#
#                                          display            ram         rom  \
# 154  14 inches, 1920 x 1200 pixels, Touch Screen     16 GB  RAM  512 GB SSD
# 156  14 inches, 1920 x 1200 pixels, Touch Screen     16 GB  RAM  256 GB SSD
# ...

# %%
df['warranty']=df['warranty'].replace("Backlit Keyboard",np.nan)

# %%
df['warranty'].value_counts()
# Out:
# 1 Year Warranty    691
# 2 Year Warranty     40
# 3 Year Warranty     10
# Name: warranty, dtype: int64

# %%
df['core'].value_counts()
# Out:
# Quad Core, 8 Threads               119
# 10 Cores (2P + 8E), 12 Threads     105
# Hexa Core, 12 Threads              104
# Octa Core, 16 Threads               78
# 12 Cores (4P + 8E), 16 Threads      67
# Octa Core (4P + 4E), 12 Threads     49
# Dual Core, 4 Threads                47
# Dual Core, 2 Threads                37
# Hexa Core (2P + 4E), 8 Threads      33
# 14 Cores (6P + 8E), 20 Threads      32
# 10 Cores (6P + 4E), 16 Threads      22
# 24 Cores (8P + 16E), 32 Threads     13
# 16 Cores (8P + 8E), 24 Threads      10
# Octa Core                            9
# Octa Core (4P + 4E)                  7
# 5 Cores (1P + 4E), 6 Threads         4
# 12 Cores (6P + 6E)                   3
# Octa Core, 8 Threads                 3
# Quad Core, 4 Threads                 2
# 14 Cores, 20 Threads                 1
# 8 GB DDR4 RAM                        1
# Dual Core                            1
# 10 Cores                             1
# 10 Cores (8P + 2E)                   1
# ...

# %%
temp_df9=df[df['core'].str.contains("RAM")]

# %%
temp_df9['core']=np.nan
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\284275003.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df9['core']=np.nan

# %%
df.loc[temp_df9.index,temp_df9.columns]=temp_df9.values

# %%
df['core'].value_counts()
# Out:
# Quad Core, 8 Threads               119
# 10 Cores (2P + 8E), 12 Threads     105
# Hexa Core, 12 Threads              104
# Octa Core, 16 Threads               78
# 12 Cores (4P + 8E), 16 Threads      67
# Octa Core (4P + 4E), 12 Threads     49
# Dual Core, 4 Threads                47
# Dual Core, 2 Threads                37
# Hexa Core (2P + 4E), 8 Threads      33
# 14 Cores (6P + 8E), 20 Threads      32
# 10 Cores (6P + 4E), 16 Threads      22
# 24 Cores (8P + 16E), 32 Threads     13
# 16 Cores (8P + 8E), 24 Threads      10
# Octa Core                            9
# Octa Core (4P + 4E)                  7
# 5 Cores (1P + 4E), 6 Threads         4
# 12 Cores (6P + 6E)                   3
# Octa Core, 8 Threads                 3
# Quad Core, 4 Threads                 2
# 14 Cores, 20 Threads                 1
# 11 Cores (5P + 6E)                   1
# 16 Cores, 32 Threads                 1
# Octa Core, 12 Threads                1
# Quad Core                            1
# ...

# %%
df['intel_core'].value_counts()
# Out:
# 12th Gen Intel Core i5 1235U       45
# 12th Gen Intel Core i5 12450H      40
# 11th Gen Intel Core i3 1115G4      32
# 12th Gen Intel Core i3 1215U       29
# 13th Gen Intel Core i5 1335U       26
# 12th Gen Intel Core i5 12500H      20
# 7th Gen AMD Ryzen 5 7520U          18
# 11th Gen Intel Core i5 1155G7      18
# 13th Gen Intel Core i5 13500H      15
# 12th Gen Intel Core i7 12650H      15
# 7th Gen AMD Ryzen 3 7320U          15
# 5th Gen AMD Ryzen 5 5600H          14
# 13th Gen Intel Core i9 13900H      13
# 11th Gen Intel Core i5 1135G7      13
# 12th Gen Intel Core i5 1240P       12
# 13th Gen Intel Core i7 1355U       11
# 12th Gen Intel Core i7 1255U       11
# 11th Gen Intel Core i5 11260H      11
# Intel Celeron  N4020               11
# 13th Gen Intel Core i7 13700H      11
# 7th Gen AMD Ryzen 7 7840HS         10
# 13th Gen Intel Core i7 13700HX     10
# 5th Gen AMD Ryzen 5  5500U         10
# Intel Celeron N4500                10
# 5th Gen AMD Ryzen 5  5600H          9
# ...

# %%
df['intel_core']=df['intel_core'].str.strip()

# %% [markdown]
# # Creating the features

# %%
df['brand']=df['name'].str.split().str[0]

# %%
df['brand'].value_counts()
# Out:
# HP           163
# Lenovo       154
# Asus         144
# Acer          78
# Dell          74
# MSI           50
# Apple         17
# Samsung       16
# Infinix       14
# Zebronics      8
# Ultimus        5
# Avita          4
# Gigabyte       4
# Primebook      4
# Xiaomi         3
# Wings          3
# Tecno          3
# Honor          2
# Chuwi          2
# Realme         2
# Microsoft      2
# Fujitsu        2
# iBall          1
# Jio            1
# Walker         1
# AXL            1
# ‎Lenovo        1
# Vaio           1
# Name: brand, dtype: int64

# %%
temp_df10=df[df['name'].str.contains("Gaming")]

# %%
temp_df10['Gaming']="gaming"
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\469816452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df10['Gaming']="gaming"

# %%
df.loc[temp_df10.index,temp_df10.columns]=temp_df10.values

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# ...

# %%
df[df['Touchscreen']=='touchscreen']['name']
# Out:
# 0      HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...
# 99     Asus ROG Flow X13 GV301RC-LJ073WS Gaming Lapto...
# 124    Asus Vivobook S14 Flip 2022 TN3402QA-LZ741WS L...
# 132    HP Chromebook 14a-na1004TU Laptop (Celeron N45...
# 154    Dell Latitude 7440 14 Laptop (13th Gen Core i5...
# 155    Lenovo Yoga 7 82YM0074IN Laptop (AMD Ryzen 7 7...
# 156    Dell Latitude 7440 Laptop (13th Gen Core i5/ 1...
# 191    HP Pavilion x360 14-ek1010TU Laptop (13th Gen ...
# 205    Asus Vivobook 15 Touch X515EA-EZ311WS Laptop (...
# 208    Lenovo Tab Yoga Duet 7 (11th Gen Core i5/ 8GB/...
# 230    Asus Chromebook CX1400FKA-EC0158 Laptop (Celer...
# 257    Dell XPS 17 9730 Laptop (13th Gen Core i9/ 32G...
# 269    Asus ROG Flow Z13 2023 GZ301VV-MU014WS Gaming ...
# 301    Asus Vivobook S14 Flip 2022 TN3402QA-LZ501WS L...
# 303    HP Pavilion x360 14-ek0074TU Laptop (12th Gen ...
# 330    Lenovo Yoga 7 82YL0095IN Laptop (13th Gen Core...
# ...

# %%
df['Touchscreen'].fillna("not-touchscreen",inplace=True)

# %%
df['Gaming'].fillna("not-gaming",inplace=True)

# %%
df.head()
# Out:
#    index                                               name  price       os  \
# 0      1  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000  windows
# 1      2  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990  windows
# 2      3  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990  windows
# 3      4  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990  windows
# 4      5  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790  windows
#
#                        graphics  \
# 0      4 GB AMD Radeon RX 6500M
# 1            Intel UHD Graphics
# 2      Intel Integrated Iris Xe
# 3  4 GB NVIDIA GeForce GTX 1650
# 4        Intel Iris Xe Graphics
#
#                                          display               ram  \
# 0  15.6 inches, 1920 x 1080 pixels, Touch Screen     8 GB DDR4 RAM
# 1                15.6 inches, 1920 x 1080 pixels     8 GB DDR4 RAM
# 2                  14 inches, 2240 x 1400 pixels  16 GB LPDDR5 RAM
# ...

# %%
df['display_inches']=df['display'].str.split("inches").str[0]

# %%
df['resolution_width']=df['display'].str.split("x").str[0].str.split(",").str[-1]

# %%
df['resolution_height']=df['display'].str.split("x").str[1].str.split("pi").str[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              760 non-null    int64
#  1   name               760 non-null    object
#  2   price              760 non-null    int32
#  3   os                 756 non-null    object
#  4   graphics           760 non-null    object
#  5   display            760 non-null    object
#  6   ram                760 non-null    object
#  7   rom                755 non-null    object
#  8   warranty           741 non-null    object
#  9   rating             492 non-null    float64
#  10  core               757 non-null    object
#  11  intel_core         760 non-null    object
#  12  Touchscreen        760 non-null    object
#  13  brand              760 non-null    object
#  14  Gaming             760 non-null    object
#  15  display_inches     760 non-null    object
# ...

# %%
df['display_inches']=df['display_inches'].astype(float)

# %%
df['resolution_width']=df['resolution_width'].astype(int)

# %%
df['resolution_height']=df['resolution_height'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              760 non-null    int64
#  1   name               760 non-null    object
#  2   price              760 non-null    int32
#  3   os                 756 non-null    object
#  4   graphics           760 non-null    object
#  5   display            760 non-null    object
#  6   ram                760 non-null    object
#  7   rom                755 non-null    object
#  8   warranty           741 non-null    object
#  9   rating             492 non-null    float64
#  10  core               757 non-null    object
#  11  intel_core         760 non-null    object
#  12  Touchscreen        760 non-null    object
#  13  brand              760 non-null    object
#  14  Gaming             760 non-null    object
#  15  display_inches     760 non-null    float64
# ...

# %%
temp_df11=df[df['ram'].str.contains("128")]

# %%
temp_df11['rom']=temp_df11['ram']
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\43660533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df11['rom']=temp_df11['ram']

# %%
temp_df11['ram']=np.nan
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\2409572047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df11['ram']=np.nan

# %%
df.loc[temp_df11.index,temp_df11.columns]=temp_df11.values

# %%
df['ram_gb']=df['ram_gb'].str.strip()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Python Scripts\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\Documents\Python Scripts\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Python Scripts\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram_gb'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['ram_gb'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Python Scripts\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\Documents\Python Scripts\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Documents\Python Scripts\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ram_gb'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['ram_gb']=2

# %%
df.drop(columns="ram_gb",inplace=True)

# %%
df['ram_gb']=df['ram'].str.split("GB").str[0]

# %%
df['ram_gb'].value_counts()
# Out:
# 16     382
# 8      321
# 32      23
# 4       22
# 64       4
# 18       3
# 12       2
# 36       1
# 2        1
# Name: ram_gb, dtype: int64

# %%
df['ram_type']=df['ram'].str.split("RAM").str[0].str.split("GB").str[-1]

# %%
df['ram_type'].value_counts()
# Out:
#  DDR4               445
#  DDR5               114
#  LPDDR5              83
#  LPDDR4X             31
#                      21
#  LPDDR4              18
#  LPDDR4x             11
#   LPDDR5              8
#  DDR4                 7
#  LPDDR5               6
#  LPDDR5X              4
#  Unified Memory       4
#  DDR3                 1
#  DDR4-                1
#  DDR5                 1
#  LPDDR5x              1
#  LPDDR4x              1
#  DDR5 SD              1
#  ‎LPDDR4              1
# Name: ram_type, dtype: int64

# %%
df['ram_type']=df['ram_type'].str.strip()

# %%
df['ram_type']=df['ram_type'].replace("LPDDR4x","LPDDR4X")

# %%
df['ram_type']=df['ram_type'].replace("LPDDR5x","LPDDR5X")

# %%
df['ram_type']=df['ram_type'].replace("DDR4-","DDR4")

# %%
df['ram_type']=df['ram_type'].replace("DDR5 SD","DDR5")

# %%
df['ram_type'].fillna("",inplace=True)

# %%
df['ram_type']=df['ram_type'].apply(lambda x:"LPDDR4" if "LPDDR4" in x and "X" not in x else x)

# %%
df['ram_type'].value_counts()
# Out:
# DDR4              453
# DDR5              116
# LPDDR5             97
# LPDDR4X            43
#                    22
# LPDDR4             19
# LPDDR5X             5
# Unified Memory      4
# DDR3                1
# Name: ram_type, dtype: int64

# %%
df['ram_type']=df['ram_type'].replace("",np.nan)

# %%
df['rom_gb']=df['rom'].str.split("GB").str[0]

# %%
df['rom_gb'].value_counts()
# Out:
# 512                     556
# 1 TB SSD                118
# 256                      38
# 128                      15
# 1 TB Hard Disk+ 256      13
# 64                        7
# 2 TB SSD                  5
# 4 TB SSD                  2
# 32                        2
# Name: rom_gb, dtype: int64

# %%
df['rom_gb'].fillna("",inplace=True)

# %%
temp_df12=df[df['rom_gb'].str.contains("SSD")]

# %%
temp_df12['rom_gb']=temp_df12['rom_gb'].str.split("TB").str[0].astype(int)*1024
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\2574232992.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df12['rom_gb']=temp_df12['rom_gb'].str.split("TB").str[0].astype(int)*1024

# %%
temp_df12['rom_gb']
# Out:
# 27     1024
# 40     1024
# 57     1024
# 68     1024
# 76     4096
# 87     1024
# 99     1024
# 109    1024
# 110    1024
# 114    1024
# 122    1024
# 123    1024
# 142    1024
# 143    1024
# 144    1024
# 151    1024
# 155    1024
# 160    1024
# 166    1024
# 167    1024
# 179    1024
# 181    1024
# 185    4096
# 186    1024
# 191    1024
# 214    1024
# 226    1024
# 229    1024
# 233    1024
# 235    1024
# 236    1024
# 237    1024
# 249    1024
# 251    1024
# 257    1024
# 264    1024
# 265    1024
# 268    1024
# 269    1024
# 282    1024
# 287    2048
# 288    1024
# 293    1024
# 322    1024
# 327    1024
# 330    1024
# 340    1024
# 341    2048
# 349    1024
# 350    1024
# 351    1024
# 358    1024
# 362    1024
# 365    1024
# 368    1024
# 370    1024
# 374    1024
# 382    1024
# 384    1024
# 388    2048
# 389    1024
# 394    1024
# 399    1024
# 404    1024
# 416    1024
# 430    1024
# 436    1024
# 462    1024
# 465    1024
# 466    1024
# 468    1024
# ...

# %%
df.loc[temp_df12.index,temp_df12.columns]=temp_df12.values

# %%
df['rom_gb'].value_counts()
# Out:
# 512                    556
# 1024                   118
# 256                     38
# 128                     15
# 1 TB Hard Disk+ 256     13
# 64                       7
# 2048                     5
#                          4
# 4096                     2
# 32                       2
# Name: rom_gb, dtype: int64

# %%
df['rom_gb'].fillna("",inplace=True)

# %%
temp_df13=df[df['rom_gb']=='1 TB Hard Disk+ 256']

# %%
temp_df13['rom_gb'].value_counts()
# Out:
# 1280    13
# Name: rom_gb, dtype: int64

# %%
df['rom_gb']=df['rom_gb'].str.strip()

# %%
df.loc[temp_df13.index,temp_df13.columns]=temp_df13.values

# %%
df['rom_gb'].value_counts()
# Out:
# 512     556
# 256      38
# 128      15
# 1280     13
# 64        7
#           4
# 32        2
# Name: rom_gb, dtype: int64

# %%
df['rom'].fillna("",inplace=True)

# %%
df['rom'].value_counts()
# Out:
# 512 GB SSD                      555
# 1 TB SSD                        118
# 256 GB SSD                       38
# 1 TB Hard Disk+ 256 GB SSD       13
# 128 GB SSD                        8
# 128 GB Hard Disk                  7
# 2 TB SSD                          5
# 64 GB Hard Disk                   4
#                                   4
# 64 GB SSD                         3
# 4 TB SSD                          2
# 32 GB Hard Disk                   2
# 512 GB Hard Disk+ 512 GB SSD      1
# Name: rom, dtype: int64

# %%
df[df['rom'].str.contains("SSD")]
# Out:
#      index                                               name     price  \
# 0      1.0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...   52000.0
# 1      2.0  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...   37990.0
# 2      3.0  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...   59990.0
# 3      4.0  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...   55990.0
# 4      5.0  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...   39790.0
# 5      6.0  HP 15s-fq2510tu Laptop (11th Gen Core i5/ 16GB...   49590.0
# 6      7.0  Dell Inspiron 3520 D560896WIN9B Laptop (12th G...   37490.0
# 7      8.0  Acer One 14 Z8-415 Laptop (11th Gen Core i3 / ...   26990.0
# 8      9.0  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...   75999.0
# 9     10.0  Wings Nuvobook V1 Laptop (11th Gen Core i5/ 8G...   29990.0
# 10    11.0  Asus TUF Gaming F15 2022 FX507ZC4-HN116W Gamin...   85800.0
# 11    12.0  Asus VivoBook 15 X515EA-EJ522WS Laptop (11th G...   47500.0
# ...

# %%
 df['rom_type']=df['rom'].apply(lambda x: 
                                  'SSD' if 'SSD' in x and 'Hard Disk' not in x 
                                  else 'Hard Disk' if 'Hard Disk' in x and 'SSD' not in x 
                                  else 'SSD+ Hard Disk')

# %%
df[['rom','rom_gb','rom_type']]
# Out:
#                               rom               rom_gb        rom_type
# 0                      512 GB SSD                  512             SSD
# 1                      512 GB SSD                  512             SSD
# 2                      512 GB SSD                  512             SSD
# 3                      512 GB SSD                  512             SSD
# 4                      512 GB SSD                  512             SSD
# 5                      512 GB SSD                  512             SSD
# 6                      512 GB SSD                  512             SSD
# 7                      512 GB SSD                  512             SSD
# 8                      256 GB SSD                  256             SSD
# 9                      512 GB SSD                  512             SSD
# 10                     512 GB SSD                  512             SSD
# 11                     512 GB SSD                  512             SSD
# ...

# %%
temp_df14=df[df['rom_gb'].isna()]

# %%
temp_df14
# Out:
#      index                                               name     price  \
# 27    28.0  Dell G15-5520 2023 Laptop (12th Gen Core i5/ 1...   77490.0
# 40    41.0  Infinix Zerobook 2023 Laptop (13th Gen Core i9...   79990.0
# 57    58.0  Acer Predator Helios Neo 16 2023 PHN16-71 Gami...  144990.0
# 68    69.0  Dell Inspiron 5430 Laptop (13th Gen Core i7/ 1...   86990.0
# 76    77.0  MSI Titan GT77 HX 13VI-092IN Gaming Laptop (13...  570990.0
# 87    88.0  Asus TUF Gaming F15 FX577ZC-HN192W Gaming Lapt...   96990.0
# 99   100.0  Asus ROG Flow X13 GV301RC-LJ073WS Gaming Lapto...  131990.0
# 109  110.0  HP Victus 15-fa1145TX Gaming Laptop (12th Gen ...   71500.0
# 110  111.0  Asus TUF Gaming F15 FX506HE-HN385WS Gaming Lap...   89870.0
# 114  115.0  Lenovo IdeaPad Slim 5 14IAH8 83BF0045IN Laptop...   57990.0
# 122  123.0  Acer Predator Helios Neo 16 PHN16-71 Gaming La...  110650.0
# 123  124.0  HP Omen 16-n0123AX Gaming Laptop (AMD Ryzen 7 ...  109990.0
# ...

# %%
temp_df14['rom_gb']=temp_df14['rom'].str.split("TB").str[0].astype(int)*1024
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\3797580052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df14['rom_gb']=temp_df14['rom'].str.split("TB").str[0].astype(int)*1024

# %%
df.loc[temp_df14.index,temp_df14.columns]=temp_df14.values

# %%
df['rom_gb'].value_counts()
# Out:
# 512                    556
# 1024                   118
# 256                     38
# 128                     15
# 1 TB Hard Disk+ 256     13
# 64                       7
# 2048                     5
#                          4
# 4096                     2
# 32                       2
# Name: rom_gb, dtype: int64

# %%
temp_df_rom=df[df['rom_gb']=='1 TB Hard Disk+ 256']

# %%
df[['rom','rom_gb','rom_type']]

# %%
df['rom_gb']=df['rom_gb'].replace("",np.nan)

# %%
df.info()

# %%
df['core'].fillna("",inplace=True)
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\475557853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['core'].fillna("",inplace=True)

# %%
df['core_count']=df['core'].str.split("Core").str[0].apply(lambda x: 
                                    2 if 'Dual' in x 
                                    else 4 if 'Quad' in x 
                                    else 6 if 'Hexa' in x 
                                    else 8 if 'Octa' in x 
                                    else x )
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\2661891412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['core_count']=df['core'].str.split("Core").str[0].apply(lambda x:

# %%
df['core'].fillna("",inplace=True)
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\475557853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['core'].fillna("",inplace=True)

# %%
df['core_count']=df['core_count'].apply(lambda x: np.nan if x == "20 Threads" else x)
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\342416126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['core_count']=df['core_count'].apply(lambda x: np.nan if x == "20 Threads" else x)

# %%
df['core_count'].fillna("",inplace=True)
# Out:
# C:\Users\disha\AppData\Local\Temp\ipykernel_18372\108872162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['core_count'].fillna("",inplace=True)

# %%
df['core_count'].value_counts()
# Out:
# 8      147
# 6      137
# 10     130
# 4      122
# 2       85
# 12      71
# 14      34
# 24      14
# 16      11
#          4
# 5        4
# 11       1
# Name: core_count, dtype: int64

# %%
df['graphics'].value_counts()
# Out:
# Intel Iris Xe Graphics                      72
# Intel UHD Graphics                          60
# 4 GB NVIDIA GeForce RTX 3050                55
# Intel Integrated UHD                        54
# Intel Integrated Iris Xe                    44
# 4 GB NVIDIA GeForce RTX 2050                44
# AMD Radeon Graphics                         41
# AMD Radeon AMD                              39
# 8 GB NVIDIA GeForce RTX 4060                26
# 6 GB NVIDIA GeForce RTX 4050                26
# 4 GB NVIDIA GeForce GTX 1650                24
# Intel Integrated UHD Graphics               16
# Integrated Intel Iris Xe Graphics           15
# Intel Iris Xe                               14
# AMD Radeon                                  14
# 8 GB NVIDIA GeForce RTX 4070                12
# 6 GB NVIDIA GeForce RTX 3050                 8
# Intel Integrated Integrated                  8
# Intel Integrated                             8
# Intel Graphics                               7
# ...

# %%
df['gpu_brand']=df['graphics'].apply(lambda x:"Intel" if "Intel" in x 
                    else "NVIDIA" if "NVIDIA" in x
                    else "AMD" if "AMD" in x
                    else "Apple" if "Apple" in x
                    else "NVIDIA" if "Nvidia" in x
                    else "Qualcomm" if "Qualcomm" in x
                    else "ARM" if "Arm" in x
                    else "MediaTek" if "MediaTek" in x
                    else "")

# %%
df['gpu_name']=df.apply(lambda row: row['graphics'].replace(row['gpu_brand'], '').strip(), axis=1)

# %%
df['gpu_name'].value_counts()
# Out:
# Iris Xe Graphics                      73
# UHD Graphics                          60
# 4 GB  GeForce RTX 3050                55
# Integrated UHD                        54
# Radeon                                53
# 4 GB  GeForce RTX 2050                44
# Integrated Iris Xe                    44
# Radeon Graphics                       41
# 6 GB  GeForce RTX 4050                26
# 8 GB  GeForce RTX 4060                26
# 4 GB  GeForce GTX 1650                24
# Integrated  Iris Xe Graphics          21
# Integrated UHD Graphics               16
# Iris Xe                               14
# 8 GB  GeForce RTX 4070                12
# Integrated                            10
# Graphics                               8
# 6 GB  GeForce RTX 3050                 8
# Integrated Integrated                  8
# ‎ Iris Xe Graphics                     7
# 6 GB  GeForce RTX 3060                 6
# 4 GB  Geforce RTX 3050                 4
# Iris XE Graphics                       4
# ...

# %%
df['cpu_gen']=df['intel_core'].str.split("Gen").str[0].str.split("th").str[0]

# %%
df['cpu_gen']=df['cpu_gen'].apply(lambda x: '3' if "3rd" in x
                    else '2' if '2nd' in x
                    else 0 if "Intel" in x
                   else 0 if "Apple" in x
                   else 0 if "MediaTek" in x
                   else 0 if "AMD" in x
                    else 0 if "Mediatek" in x
                   else x)

# %%
df['cpu_gen']=df['cpu_gen'].astype("int")

# %%
df['intel_core'].value_counts()
# Out:
# 12th Gen Intel Core i5 1235U       46
# 12th Gen Intel Core i5 12450H      42
# 11th Gen Intel Core i3 1115G4      34
# 12th Gen Intel Core i3 1215U       29
# 13th Gen Intel Core i5 1335U       26
# 12th Gen Intel Core i5 12500H      23
# 7th Gen AMD Ryzen 5 7520U          19
# 11th Gen Intel Core i5 1135G7      18
# 11th Gen Intel Core i5 1155G7      18
# 12th Gen Intel Core i7 12650H      16
# 7th Gen AMD Ryzen 3 7320U          15
# 13th Gen Intel Core i5 13500H      15
# 5th Gen AMD Ryzen 5  5600H         15
# 5th Gen AMD Ryzen 5 5600H          15
# 13th Gen Intel Core i7 1355U       13
# 13th Gen Intel Core i9 13900H      13
# Intel Celeron  N4020               12
# 12th Gen Intel Core i5 1240P       12
# 5th Gen AMD Ryzen 5  5500U         12
# 13th Gen Intel Core i7 13700H      11
# 11th Gen Intel Core i5 11260H      11
# 12th Gen Intel Core i7 1255U       11
# Intel Celeron N4500                10
# 12th Gen Intel Core i7 12700H      10
# 13th Gen Intel Core i7 13700HX     10
# ...

# %%
df['cpu_brand']=df['intel_core'].apply(lambda x: 'Intel' if "Intel" in x
                    else "Qualcomm" if "Qualcomm" in x
                   else "Apple" if "Apple" in x
                   else "MediaTek" if "MediaTek" in x
                   else "AMD" if "AMD" in x
                    else "MediaTek" if "Mediatek" in x
                    else "AMD" if "Amd" in x
                    else "Intel" if "intel" in x
                   else x)

# %%
df['cpu_brand'].value_counts()
# Out:
# Intel       523
# AMD         213
# Apple        17
# MediaTek      6
# Qualcomm      1
# Name: cpu_brand, dtype: int64

# %%
df['intel_core'].value_counts()
# Out:
# 12th Gen Intel Core i5 1235U       46
# 12th Gen Intel Core i5 12450H      42
# 11th Gen Intel Core i3 1115G4      34
# 12th Gen Intel Core i3 1215U       29
# 13th Gen Intel Core i5 1335U       26
# 12th Gen Intel Core i5 12500H      23
# 7th Gen AMD Ryzen 5 7520U          19
# 11th Gen Intel Core i5 1135G7      18
# 11th Gen Intel Core i5 1155G7      18
# 12th Gen Intel Core i7 12650H      16
# 7th Gen AMD Ryzen 3 7320U          15
# 13th Gen Intel Core i5 13500H      15
# 5th Gen AMD Ryzen 5  5600H         15
# 5th Gen AMD Ryzen 5 5600H          15
# 13th Gen Intel Core i7 1355U       13
# 13th Gen Intel Core i9 13900H      13
# Intel Celeron  N4020               12
# 12th Gen Intel Core i5 1240P       12
# 5th Gen AMD Ryzen 5  5500U         12
# 13th Gen Intel Core i7 13700H      11
# 11th Gen Intel Core i5 11260H      11
# 12th Gen Intel Core i7 1255U       11
# Intel Celeron N4500                10
# 12th Gen Intel Core i7 12700H      10
# 13th Gen Intel Core i7 13700HX     10
# ...

# %%
x=df['intel_core'].str.split("Gen").str[1]

# %%
x=x.str.strip()

# %%
df['cpu_name']=x

# %% [markdown]
# df.columns

# %%
df.columns
# Out:
# Index(['index', 'name', 'price', 'os', 'graphics', 'display', 'ram', 'rom',
#        'warranty', 'rating', 'core', 'intel_core', 'Touchscreen', 'brand',
#        'Gaming', 'display_inches', 'resolution_width', 'resolution_height',
#        'ram_gb', 'ram_type', 'rom_gb', 'rom_type', 'core_count', 'gpu_brand',
#        'gpu_name', 'cpu_gen', 'cpu_brand', 'cpu_name'],
#       dtype='object')

# %%
df['brand']=df['brand'].apply(lambda x:"Lenovo" if "Lenovo" in x else x)

# %%
df.drop(columns={"graphics",'display','ram','rom','core','intel_core'})
# Out:
#      index                                               name     price  \
# 0      1.0  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...   52000.0
# 1      2.0  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...   37990.0
# 2      3.0  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...   59990.0
# 3      4.0  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...   55990.0
# 4      5.0  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...   39790.0
# 5      6.0  HP 15s-fq2510tu Laptop (11th Gen Core i5/ 16GB...   49590.0
# 6      7.0  Dell Inspiron 3520 D560896WIN9B Laptop (12th G...   37490.0
# 7      8.0  Acer One 14 Z8-415 Laptop (11th Gen Core i3 / ...   26990.0
# 8      9.0  Apple MacBook Air 2020 MGND3HN Laptop (Apple M...   75999.0
# 9     10.0  Wings Nuvobook V1 Laptop (11th Gen Core i5/ 8G...   29990.0
# 10    11.0  Asus TUF Gaming F15 2022 FX507ZC4-HN116W Gamin...   85800.0
# 11    12.0  Asus VivoBook 15 X515EA-EJ522WS Laptop (11th G...   47500.0
# ...

# %%
df['warranty'].value_counts()
# Out:
# 1     691
# 2      40
# 3      10
# Name: warranty, dtype: int64

# %%
df=df[['index','brand','name','price','Touchscreen','Gaming','os','warranty','display_inches','resolution_width','resolution_height','ram_gb','ram_type','rom_gb','rom_type','core_count','gpu_brand','gpu_name','cpu_gen','cpu_brand','cpu_name','rating']]

# %%
df.head()
# Out:
#    index   brand                                               name    price  \
# 0    1.0      HP  HP Victus 15-fb0157AX Gaming Laptop (AMD Ryzen...  52000.0
# 1    2.0      HP  HP 15s-fq5007TU Laptop (12th Gen Core i3/ 8GB/...  37990.0
# 2    3.0  Lenovo  Lenovo Yoga Slim 6 14IAP8 82WU0095IN Laptop (1...  59990.0
# 3    4.0  Lenovo  Lenovo IdeaPad Gaming 3 15IHU6 82K101GSIN Lapt...  55990.0
# 4    5.0    Acer  Acer Aspire Lite AL15-51 2023 Laptop (11th Gen...  39790.0
#
#        Touchscreen      Gaming       os warranty  display_inches  \
# 0      touchscreen      gaming  windows       1             15.6
# 1  not-touchscreen  not-gaming  windows       1             15.6
# 2  not-touchscreen  not-gaming  windows       1             14.0
# 3  not-touchscreen      gaming  windows       1             15.6
# 4  not-touchscreen  not-gaming  windows       1             15.6
#
#    resolution_width  ...  ram_type rom_gb rom_type core_count gpu_brand  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 760 entries, 0 to 759
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              760 non-null    float64
#  1   brand              760 non-null    object
#  2   name               760 non-null    object
#  3   price              760 non-null    float64
#  4   Touchscreen        760 non-null    object
#  5   Gaming             760 non-null    object
#  6   os                 756 non-null    object
#  7   warranty           741 non-null    object
#  8   display_inches     760 non-null    float64
#  9   resolution_width   760 non-null    float64
#  10  resolution_height  760 non-null    float64
#  11  ram_gb             759 non-null    object
#  12  ram_type           760 non-null    object
#  13  rom_gb             635 non-null    object
#  14  rom_type           760 non-null    object
#  15  core_count         760 non-null    object
# ...

# %%
df['rating'].value_counts()
# Out:
# 64.0    42
# 60.0    39
# 70.0    37
# 67.0    36
# 65.0    36
# 62.0    34
# 71.0    32
# 66.0    30
# 72.0    29
# 63.0    28
# 69.0    23
# 75.0    18
# 73.0    18
# 77.0    14
# 76.0    10
# 79.0     9
# 61.0     7
# 68.0     7
# 78.0     7
# 74.0     6
# 80.0     6
# 83.0     5
# 84.0     5
# 88.0     3
# 81.0     3
# 85.0     3
# 82.0     2
# 89.0     2
# 86.0     1
# Name: rating, dtype: int64

# %%
df.to_csv("cleaned_laptop.csv")
